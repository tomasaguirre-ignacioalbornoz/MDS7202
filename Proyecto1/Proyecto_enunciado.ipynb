# %% [markdown]
# ![](https://www.dii.uchile.cl/wp-content/uploads/2021/06/Magi%CC%81ster-en-Ciencia-de-Datos.png)

# %% [markdown]
# # **Proyecto 1 - MDS7202 Laboratorio de Programación Científica para Ciencia de Datos 📚**
#
# **MDS7202: Laboratorio de Programación Científica para Ciencia de Datos**
#
# ### Cuerpo Docente:
#
# - Profesor: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz
#
# *Por favor, lean detalladamente las instrucciones de la tarea antes de empezar a escribir.*
#
# ### Equipo:
#
# - Tomás Aguirre
# - Ignacio Albornoz
#
#
# ### Link de repositorio de GitHub: https://github.com/tomasaguirre-ignacioalbornoz/MDS7202
#
# Fecha límite de entrega 📆: 27 de Octubre de 2023.

# %% [markdown]
# ----
#
# ## Reglas
#
# - **Grupos de 2 personas.**
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Estrictamente prohibida la copia.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://worldskateamerica.org/wp-content/uploads/2023/07/SANTIAGO-2023-1-768x153.jpg" alt="Descripción de la imagen">
# </div>
#
# En un Chile azotado por un profundo caos político-económico y el resurgimiento de programas de televisión de dudosa calidad, todas las miradas y esperanzas son depositadas en el éxito de un único evento: Santiago 2023. La nación necesitaba desesperadamente un respiro, y los Juegos de Santiago 2023 prometían ser una luz al final del túnel.
#
# El Presidente de la República -conocido en las calles como Bombín-, consciente de la importancia de este evento para la revitalización del país, decide convocar a usted y su equipo en calidad de expertos en análisis de datos y estadísticas. Con gran solemnidad, el presidente les encomienda una importante y peligrosa: liderar un proyecto que permitiera caracterizar de forma automática y eficiente los datos generados por estos magnos juegos. Para esto, el presidente le destaca que la solución debe considerar los siguientes puntos:
# - Caracterización automática de los datos
# - La solución debe ser compatible con cualquier dataset
# - Se les facilita el dataset *olimpiadas.parquet*, el cual recopila data de diferentes juegos olímpicos realizados en los últimos años

# %% [markdown]
# ## 1.1 Creación de `Profiler` Class (4.0 puntos)
#
# Cree la clase `Profiler`. Como mínimo, esta debe tener las siguientes funcionalidades:
#
# 1. El método constructor, el cual debe recibir los datos a procesar en formato `Pandas DataFrame`. Además, este método debe generar una carpeta en su directorio de trabajo con el nombre `EDA_fecha`, donde `fecha` corresponda a la fecha de ejecución en formato `DD-MM-YYYY`.
#
# 2. El método `summarize`, el cual debe caracterizar las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Reportar el tipo de variable
#     - Reportar el número y/o porcentaje de valores únicos de la variable
#     - Reportar el número y/o porcentaje de valores nulos
#     - Si la variables es numérica:
#         - Reportar el número y/o porcentaje de valores cero, negativos y outliers
#         - Reportar estadística descriptiva como el valor mínimo, máximo, promedio y los percentiles 25, 50, 75 y 100
#    - Levantar una alerta en caso de encontrar alguna anomalía fuera de lo común (el criterio debe ser ajustable por el usuario)
#    - Guardar sus resultados en el directorio `EDA_fecha/summary.txt`. El archivo debe separar de forma clara y ordenada los resultados de cada punto.
#
# 3. El método `plot_vars`, el cual debe graficar la distribución e interraciones de las variables del Dataset. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/plots`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Para las variables numéricas:
#         - Genere un gráfico de distribución de densidad
#         - Grafique la correlación entre las variables
#     - Para las variables categóricas:
#         - Genere un histograma de las top N categorías (N debe ser un parámetro ajustable)
#         - Grafique el coeficiente V de Cramer entre las variables
#     - Guardar cada gráfico generado en la carpeta `EDA_fecha/plots` en formato `.pdf` y bajo el naming `variable.pdf`, donde `variable` es el nombre de la variable de interés
#
# 4. El método `clean_data`, el cual debe limpiar los datos para que luego puedan ser procesados. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clean_data`
#     - Implementar una funcionalidad para filtrar y aplicar este método a una o más variables de interés.
#     - Drop de valores duplicados
#     - Implementar como mínimo 2 técnicas para tratar los valores nulos, como:
#         - Drop de valores nulos
#         - Imputar valores nulos con alguna técnica de imputación
#         - Funcionalidad para escoger entre una técnica y la otra.
#     - Una de las columnas del dataframe presenta datos *no atómicos*. Separe dicha columna en las columnas que la compongan.
#         - Hint: ¿Qué caracteres permiten separar una columna de otra?
#         - Para las pruebas con el dataset nuevo, puede esperar que exista al menos una columna con este tipo de problema. Asuma que los separadores serán los mismos, aunque el número de columnas a separar puede ser distinto.
#     - Deberían usar `FunctionTransformer`.
#     - Guardar los datos procesados en formato `.csv` en el path `EDA_fecha/clean_data/data.csv`
#
# 5. El método `scale`, el cual debe preparar adecuadamente los datos para luego ser consumidos por algún tipo de algoritmo. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/scale`
#     - Procesar de forma adecuada los datos numéricos y categóricos:
#         - Su método debe recibir las técnicas de escalamiento como argumento de entrada (utilizar solo técnicas compatibles con el framework de `sklearn`)
#         - Para los atributos numéricos, se transforme los datos con un escalador logarítmico y un `MinMaxScaler`
#         - Asuma que no existen datos ordinales en su dataset
#     - Guardar todo este procesamiento en un `ColumnTransformer`.
#     - Guardar los datos limpios y transformados en formato `.csv` en el path `EDA_fecha/process/scaled_features.csv`
#
# 6. El método `make_clusters`, el cual debe generar clusters de los datos usando algún algoritmo de clusterización. Como mínimo, se espera que su método pueda:
#     - Crear la carpeta `EDA_fecha/clusters`
#     - Generar un estudio del codo donde señale la cantidad de clusters optimos para el desarrollo.
#     - Su método debe recibir el algoritmo de clustering como argumento de entrada (utilizar solo algoritmos compatibles con el framework de `sklearn`).
#     - No olvide pre procesar adecuadamente los datos antes de implementar la técnica de clustering.
#     - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#     - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#     - Una vez generado los clusters, proyecte los datos a 2 dimensiones usando su técnica de reducción de dimensionalidad favorita y grafique los resultados coloreando por cluster.
#     - Guardar los datos con su respectivo cluster en formato `.csv` en el path `EDA_fecha/clusters/data_clusters.csv`. Guarde también los gráficos generados en el mismo path.
#
# 7. El método `detect_anomalies`, el cual debe detectar anomalías en los datos. Como mínimo, se espera que su método pueda:
#
#     - Crear la carpeta `EDA_fecha/anomalies`
#     - Implementar alguna técnica de detección de anomalías.
#     - Al igual que el punto anterior, su método debe considerar los siguientes puntos:
#         - No olvide pre procesar de forma adecuada los datos antes de implementar la técnica de detección de anomalía.
#         - En este punto es espera que generen un `Pipeline` de sklearn. Además, su método debería usar lo construido en los puntos 4 y 5.
#         - Su método debe ser capaz de funcionar a partir de datos crudos (se descontará puntaje de lo contrario).
#         - Su método debe recibir el algoritmo como argumento de entrada
#         - Una vez generado las etiquetas, proyecte los datos a 2 dimensiones y grafique los resultados coloreando por las etiquetas predichas por el detector de anomalías
#     - Guardar los datos con su respectiva etiqueta en formato `.csv` en el path `EDA_fecha/anomalies/data_anomalies.csv`. Guarde también los gráficos generados en el mismo path.
#
# 8. El método `profile`, el cual debe ejecutar todos los métodos anteriores.
#
# 9. Crear el método `clearGarbage` para eliminar las carpetas/archivos creados/as por la clase `Profiler`.
#
# Algunas consideraciones generales:
# - Su clase será testeada con datos tabulares diferentes a los provistos. No desarrollen código *hardcodeado*: su clase debe ser capaz de funcionar para **cualquier** dataset.
# - Aplique todo su conocimiento sobre buenas prácticas de programación: se evaluará que su código sea limpio y ordenado.
# - Recuerden documentar cada una de las funcionalidades que implementen.
# - Recuerden adjuntar sus `requirements.txt` junto a su entrega de proyecto. **El código que no se pueda ejecutar por imcompatibilidades de librerías no será corregido.**

# %%
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from collections import Counter
import shutil
import numpy as np
import seaborn as sns
import re
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.base import BaseEstimator
from yellowbrick.cluster import KElbowVisualizer
from sklearn.base import ClusterMixin
from sklearn.svm import OneClassSVM
from matplotlib.lines import Line2D
#from kmodes.kmodes import KModes


# Lee el archivo parquet completo
df_original = pd.read_parquet('olimpiadas.parquet')

# Calcula el número de filas que corresponde a un cuarto del DataFrame original
nrows = df_original.shape[0] // 2000

# Obtiene una muestra aleatoria de 'nrows' filas del DataFrame original
df = df_original.sample(n=nrows)

# %%
class Profiler():
    """
    Clase Profiler para realizar análisis exploratorio de datos (EDA) en un DataFrame de pandas.

    Esta clase ofrece métodos para resumir estadísticas, detectar valores atípicos (outliers),
    generar visualizaciones, limpiar y escalar datos, realizar análisis de clustering y detectar anomalías.

    Atributos:
    -----------
    data : pd.DataFrame
        El DataFrame de pandas que se analizará.
    timestamp : str
        Marca de tiempo que indica cuándo se creó la instancia de Profiler, usada para crear carpetas de salida.
    output_folder : str
        Nombre de la carpeta de salida donde se guardarán todos los resultados y archivos generados por Profiler.

    Métodos:
    --------
    summarize(variables_of_interest_summarize, criteria_for_outliers)
        Resumen de estadísticas descriptivas y detección de outliers.
    plot_vars(variables_of_interest_plot, top_n_categories)
        Visualización de distribuciones y recuentos de variables de interés.
    clean_data(variables_of_interest_clean_data, drop_duplicates, drop_na, impute_na, numeric_cols)
        Limpieza y preprocesamiento básico del conjunto de datos.
    scale(scaling_technique)
        Escalado y normalización de los datos.
    make_clusters(clustering_algorithm, n_clusters_range, plot_elbow)
        Ejecución de algoritmos de clustering y evaluación de los resultados.
    detect_anomalies(anomaly_detection_algorithm)
        Detección de anomalías en el conjunto de datos.
    clearGarbage()
        Eliminación de carpetas y archivos temporales generados por la instancia de Profiler.
    """
    # 1
    def __init__(self, data):

        self.data = data
        self.timestamp = datetime.now().strftime('%d-%m-%Y')
        self.output_folder = f'EDA_{self.timestamp}'
        os.makedirs(self.output_folder, exist_ok=True)
        
        
    # 2  
    def summarize(self, variables_of_interest=None, criteria_for_outliers=None):
        """
        Resumen de las estadísticas y características de las variables en el DataFrame.

        Genera un archivo de resumen que incluye información sobre el tipo de variable, número de valores únicos, 
        porcentaje de valores únicos, número de valores nulos, porcentaje de valores nulos, número de valores cero, 
        porcentaje de valores cero, número de valores negativos, porcentaje de valores negativos y estadísticas descriptivas 
        (si la variable es numérica).

        Args:
            variables_of_interest (list or None): Lista de variables a incluir en el resumen. Si es None, se utilizan todas las columnas del DataFrame.
            criteria_for_outliers (tuple or None): Criterio para considerar outliers en variables numéricas. 
                Debe ser un par de valores (umbral_mínimo, umbral_máximo). Si es None, no se calculan los outliers.

        Returns:
            None
        """
        #print("Aplicando summarize")
        if variables_of_interest is None:
            variables_of_interest = self.data.columns

        summary_file = os.path.join(self.output_folder, 'summary.txt')
        with open(summary_file, 'w') as file:
            for column in variables_of_interest:
                if column in self.data.columns:
                    file.write(f'Variable: {column}\n')
                    file.write(f'Tipo de Variable: {self.data[column].dtype}\n')
                    file.write(f'Número de Valores Únicos: {self.data[column].nunique()}\n')
                    file.write(f'Porcentaje de Valores Únicos: {100 * self.data[column].nunique() / len(self.data):.2f}%\n')
                    file.write(f'Número de Valores Nulos: {self.data[column].isnull().sum()}\n')
                    file.write(f'Porcentaje de Valores Nulos: {100 * self.data[column].isnull().sum() / len(self.data):.2f}%\n')

                    if self.data[column].dtype in ['int64', 'float64']:
                        num_zeros = (self.data[column] == 0).sum()
                        num_negatives = (self.data[column] < 0).sum()
                        
                        file.write(f'Número de Valores Cero: {num_zeros}\n')
                        file.write(f'Porcentaje de Valores Cero: {100 * num_zeros / len(self.data):.2f}%\n')
                        file.write(f'Número de Valores Negativos: {num_negatives}\n')
                        file.write(f'Porcentaje de Valores Negativos: {100 * num_negatives / len(self.data):.2f}%\n')
                        
                        # Considerar outliers si se proporciona un criterio
                        if criteria_for_outliers is not None:
                            data_column = self.data[column]
                            min_threshold, max_threshold = criteria_for_outliers
                            num_outliers = ((data_column < min_threshold) | (data_column > max_threshold)).sum()
                            file.write(f'Número de Outliers: {num_outliers}\n')
                            file.write(f'Porcentaje de Outliers: {100 * num_outliers / len(self.data):.2f}%\n')
                    
                        statistics = self.data[column].describe()
                        file.write('Estadísticas Descriptivas:\n')
                        file.write(statistics.to_string() + '\n')
                    
                    file.write('\n')
                    
    # 3       
    def plot_vars(self, data, variables_of_interest=None, top_n_categories=5):
        """
        Genera visualizaciones para variables en el DataFrame.

        Este método crea visualizaciones que incluyen gráficos de correlación para variables numéricas, matrices de correlación
        de V de Cramer para variables categóricas y gráficos específicos para cada variable, ya sea numérica o categórica.

        Args:
            variables_of_interest (list or None): Lista de variables a incluir en las visualizaciones. Si es None, se utilizan todas las columnas del DataFrame.
            top_n_categories (int): Número de categorías principales a mostrar en gráficos de variables categóricas.

        Returns:
            None
        """
        #print("Aplicando plot_vars")
        plots_folder = os.path.join(self.output_folder, 'plots')
        os.makedirs(plots_folder, exist_ok=True)
        
        if variables_of_interest is None:
            variables_of_interest = data.columns

        numeric_variables = [var for var in variables_of_interest if pd.api.types.is_numeric_dtype(data[var])]
        categorical_variables = [var for var in variables_of_interest if pd.api.types.is_string_dtype(data[var])]
        
        # Plot de correlación entre variables numéricas
        self.plot_correlation(data, numeric_variables, plots_folder)

        # Plot de matriz de correlación de V de Cramer entre variables categóricas
        self.plot_cramers_heatmap(data, categorical_variables, plots_folder)
        
        for variable in variables_of_interest:
            if variable in data.columns:
                if pd.api.types.is_numeric_dtype(data[variable]):
                    self.plot_numeric_variable(data, variable, plots_folder)
                elif pd.api.types.is_string_dtype(data[variable]):
                    self.plot_categorical_variable(data, variable, top_n_categories, plots_folder)                     

    def plot_correlation(self, data, variables_of_interest, plots_folder):
        """
        Crea un gráfico de correlación entre variables numéricas y lo guarda como un archivo PDF.

        Args:
            variables_of_interest (list): Lista de variables numéricas para las que se calculará y representará la correlación.
            plots_folder (str): Directorio donde se guardará el archivo de gráficos.

        Returns:
            None
        """
        correlation_matrix = data[variables_of_interest].corr()
        fig, ax = plt.subplots(figsize=(10, 8))
        sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, ax=ax)
        plt.title('Correlación entre variables numéricas')
        plot_filename = os.path.join(plots_folder, 'correlation.pdf')
        plt.savefig(plot_filename, format='pdf')
        plt.close()

    def plot_numeric_variable(self, data, variable, plots_folder):
        """
        Crea un gráfico de densidad para una variable numérica y lo guarda como un archivo PDF.

        Args:
            variable (str): Nombre de la variable numérica que se representará.
            plots_folder (str): Directorio donde se guardará el archivo de gráficos.

        Returns:
            None
        """
        # Gráfico de densidad para variables numéricas usando Matplotlib
        plt.figure()
        plt.hist(data[variable], bins=30, color='blue', alpha=0.7)
        plt.xticks(rotation=45)
        plt.title(f'Distribución de {variable}')
        plot_filename = os.path.join(plots_folder, f'{variable}.pdf')
        plt.savefig(plot_filename, format='pdf')
        plt.close()
        
    def plot_categorical_variable(self, data, variable, top_n_categories, plots_folder):
        """
        Crea un histograma de las categorías más frecuentes para una variable categórica y lo guarda como un archivo PDF.

        Args:
            variable (str): Nombre de la variable categórica que se representará.
            top_n_categories (int): Número de categorías más frecuentes a incluir en el histograma.
            plots_folder (str): Directorio donde se guardará el archivo de gráficos.

        Returns:
            None
        """
        # Histograma de las top N categorías usando Matplotlib
        top_categories = data[variable].value_counts().nlargest(top_n_categories)
        fig = plt.figure()
        top_categories.plot(kind='bar', color='green', alpha=0.7)
        plt.title(f'Top {top_n_categories} Categorías de {variable}')
        plt.xticks(rotation=0)
        plot_filename = os.path.join(plots_folder, f'{variable}.pdf')
        plt.savefig(plot_filename, format='pdf')
        plt.close()


    # Define the Cramer's V function
    def cramers_V(self, var1, var2):
        """
        Calcula la medida de asociación Cramer's V entre dos variables categóricas.

        Parameters:
        - var1: Serie de datos de la primera variable categórica.
        - var2: Serie de datos de la segunda variable categórica.

        Returns:
        - El valor de Cramer's V que indica la fortaleza de la asociación entre las dos variables categóricas.
    
        Cramer's V es una estadística que mide la asociación entre dos variables categóricas. Es una medida de la fuerza y dirección de la relación entre las variables. Los valores de Cramer's V varían entre 0 y 1, donde 0 indica ninguna asociación y 1 indica una asociación perfecta.

        La función calcula Cramer's V utilizando una tabla de contingencia y el estadístico Chi-cuadrado. Cuanto mayor sea el valor de Cramer's V, mayor será la asociación entre las dos variables categóricas.
        """
        crosstab = np.array(pd.crosstab(var1, var2, rownames=None, colnames=None))  # Cross table building
        stat = chi2_contingency(crosstab)[0]  # Keeping the test statistic of the Chi2 test
        obs = np.sum(crosstab)  # Number of observations
        mini = min(crosstab.shape) - 1  # Take the minimum value between the columns and the rows of the cross table
        return np.sqrt(stat / (obs * mini))
    
    # Define el método create_cramers_matrix 
    def create_cramers_matrix(self, data, categorical_variables):
        """
        Crea una matriz de Cramer's V que mide la asociación entre variables categóricas.

        Parameters:
        - data: DataFrame que contiene los datos de las variables categóricas.
        - categorical_variables: Lista de nombres de las variables categóricas en el DataFrame.

        Returns:
        - Un DataFrame que representa la matriz de Cramer's V con valores redondeados.

        Este método calcula la asociación entre todas las combinaciones posibles de variables categóricas en el DataFrame. Utiliza la medida de Cramer's V para cuantificar la fuerza de la asociación. La matriz resultante muestra la asociación entre cada par de variables categóricas.

        Cramer's V es una estadística que varía entre 0 y 1, donde 0 indica ninguna asociación y 1 indica una asociación perfecta. Los valores de Cramer's V en la matriz están redondeados a dos decimales para facilitar la interpretación.
        """
        rows = []
        data_encoded = data.copy()
        for var1 in categorical_variables:
            col = []
            for var2 in categorical_variables:
                cramers = self.cramers_V(data_encoded[var1], data_encoded[var2])  # Cramer's V test
                col.append(round(cramers, 2))  # Keeping the rounded value of the Cramer's V
            rows.append(col)
        cramers_results = np.array(rows)
        df = pd.DataFrame(cramers_results, columns=categorical_variables, index=categorical_variables)
        return df

    
    def plot_cramers_heatmap(self, data, categorical_variables, plots_folder):
        """
        Crea un gráfico de la matriz de correlación de V de Cramer entre variables categóricas y lo guarda como un archivo PDF.

        Args:
            categorical_variables (list): Lista de variables categóricas para las que se calculará y representará la matriz de correlación de V de Cramer.
            plots_folder (str): Directorio donde se guardará el archivo de gráficos.

        Returns:
            None
        """
        cramers_matrix = self.create_cramers_matrix(data, categorical_variables)
        mask = np.zeros_like(cramers_matrix, dtype=bool)
        mask[np.triu_indices_from(mask)] = True

        with sns.axes_style("white"):
            ax = sns.heatmap(cramers_matrix, mask=mask, vmin=0., vmax=1, square=True)

        plot_filename = os.path.join(plots_folder, 'cramers_matrix.pdf')
        plt.savefig(plot_filename, format='pdf')
        plt.close()
    
    # 4
    def clean_data(self, variables_of_interest=None, drop_duplicates=True, drop_na=False, impute_na=True, numeric_cols = ['age', 'height', 'weight'], use_categorical_vars = True):
        """
        Limpia y preprocesa los datos del Profiler.

        Args:
            variables_of_interest (list): Lista de variables de interés a ser incluidas en el resultado limpio (por defecto, todas las variables).
            drop_duplicates (bool): Indica si se deben eliminar filas duplicadas (por defecto, True).
            drop_na (bool): Indica si se deben eliminar filas con valores nulos (por defecto, True).
            impute_na (bool): Indica si se deben imputar los valores nulos en las columnas (por defecto, False).
            numeric_cols (list): Lista de columnas numéricas a ser convertidas (por defecto, ['age', 'height', 'weight']).
            use_categorical_vars (bool): Indica si se deben utilizar las variables categóricas (por defecto, True).

        Returns:
            pandas.DataFrame
                Un DataFrame con la data procesada y limpia.
        """
        #print("Aplicando clean_data")
        def custom_impute_na(X):
            """
            Imputa valores nulos en un DataFrame dividiendo las columnas numéricas y categóricas,
            y reemplazando los valores nulos en las columnas numéricas con la media de la columna y
            los valores nulos en las columnas categóricas con la moda (valor más frecuente).

            Args:
                X (DataFrame): El DataFrame que contiene las columnas a ser imputadas.

            Returns:
                DataFrame: El DataFrame resultante con los valores nulos imputados.
            """
            numeric_columns = X.select_dtypes(include=[np.number])
            categorical_columns = X.select_dtypes(exclude=[np.number])

            # Imputa valores nulos en columnas numéricas con la media
            numeric_columns = numeric_columns.fillna(numeric_columns.mean())

            # Imputa valores nulos en columnas categóricas con la moda (valor más frecuente)
            categorical_columns = categorical_columns.fillna(categorical_columns.mode().iloc[0])

            return pd.concat([numeric_columns, categorical_columns], axis=1)
        
        def convert_numeric_columns(X, columns):
            """
            Convierte las columnas especificadas en el DataFrame a tipo numérico. Los valores no numéricos se
            convierten en NaN (Not-a-Number).

            Args:
                X (DataFrame): El DataFrame que contiene las columnas a convertir.
                columns (list): Una lista de nombres de columnas que se convertirán a tipo numérico.

            Returns:
                DataFrame: El DataFrame resultante con las columnas especificadas convertidas a tipo numérico.
            """
            for column in columns:
                X[column] = pd.to_numeric(X[column], errors='coerce')
            return X
        
        
        clean_data_folder = os.path.join(self.output_folder, 'clean_data')
        os.makedirs(clean_data_folder, exist_ok=True)

        data_to_clean = self.data.copy()
    
        # Detecta automáticamente la columna con datos no atómicos
        non_atomic_column = self.detect_non_atomic_column(data_to_clean)

        if non_atomic_column:
            split_column_func = FunctionTransformer(lambda x: x.apply(self.split_column), validate=False)
            separated_data = split_column_func.transform(data_to_clean[non_atomic_column])

            # Verifica que todas las listas tengan la misma longitud
            if separated_data.apply(len).nunique() == 1:
                # Obtiene los elementos separados de non_atomic_column
                column_names = non_atomic_column.split('-')
                num_columns = len(column_names)

                # Verifica que la cantidad de elementos coincida con la longitud de las listas
                if num_columns == separated_data.apply(len).iloc[0]:
                    separated_data = pd.DataFrame(separated_data.tolist(), columns=column_names)
                    data_to_clean = pd.concat([data_to_clean, separated_data], axis=1)
                    data_to_clean.drop(columns=[non_atomic_column], inplace=True)
                else:
                    print("El número de elementos separados no coincide con la longitud de las listas.")
            else:
                print("Las listas no tienen la misma longitud, no se pueden separar en columnas.")
        
        convert_numeric_func = FunctionTransformer(convert_numeric_columns, validate=False, kw_args={'columns': numeric_cols})
        data_to_clean = convert_numeric_func.transform(data_to_clean)
        
        
        if variables_of_interest is not None:
            data_to_clean = data_to_clean[variables_of_interest]

        if drop_duplicates:
            drop_duplicates_func = FunctionTransformer(lambda x: x.drop_duplicates(), validate=False)
            data_to_clean = drop_duplicates_func.transform(data_to_clean)

        if drop_na:
            drop_na_func = FunctionTransformer(lambda x: x.dropna(), validate=False)
            data_to_clean = drop_na_func.transform(data_to_clean)

        if impute_na:
            impute_na_func = FunctionTransformer(custom_impute_na, validate=False)
            data_to_clean = impute_na_func.transform(data_to_clean)
        
        if not use_categorical_vars:
            data_to_clean = data_to_clean.select_dtypes(include=[np.number])

        data_to_clean.to_csv(os.path.join(clean_data_folder, 'data.csv'), index=False)
        return data_to_clean
        
    def split_column(self, row):
        """
        Divide una columna no atómica en elementos separados utilizando una expresión regular.

        Args:
            row (str): Valor de la columna no atómica.

        Returns:
            list: Lista de elementos separados.
        """
        # Utiliza una expresión regular para buscar patrones de separadores
        return re.split(r'[*():?]', row)

    def detect_non_atomic_column(self, data):
        """
        Detecta automáticamente una columna que contiene datos no atómicos.

        Args:
            data (DataFrame): Los datos a analizar.

        Returns:
            str: El nombre de la columna con datos no atómicos, o None si no se encuentra.
        """
        # Busca una columna que contenga caracteres especiales o separadores
        for column in data.columns:
            if any(char in column for char in ('-', ';', ':', '|')):
                return column
        return None
        
    def split_column(self, row):
        """
        Divide una columna no atómica en elementos separados utilizando una expresión regular.

        Args:
            row (str): Valor de la columna no atómica.

        Returns:
            list: Lista de elementos separados.
        """
        # Utiliza una expresión regular para buscar patrones de separadores
        return re.split(r'[*():?]', row)

    def detect_non_atomic_column(self, data):
        """
        Detecta automáticamente una columna que contiene datos no atómicos.

        Args:
            data (DataFrame): Los datos a analizar.

        Returns:
            str: El nombre de la columna con datos no atómicos, o None si no se encuentra.
        """
        # Busca una columna que contenga caracteres especiales o separadores
        for column in data.columns:
            if any(char in column for char in ('-', ';', ':', '|')):
                return column
        return None
    
    def _clean_data_wrapper(self, X, y=None):
        """
        Devuelve los datos limpios independientemente de la entrada.

        Este método es un envoltorio que ignora cualquier entrada y proporciona
        una interfaz consistente para su uso en una pipeline de scikit-learn o
        transformadores similares que esperan una función con entradas X e y.

        Parámetros:
        ----------
        X : Este parámetro es ignorado.
        y : Ignorado, opcional (default=None)
            Este parámetro es ignorado.

        Retorna:
        -------
        pandas.DataFrame
            Un DataFrame que contiene los datos limpios obtenidos a través del
            método clean_data de la misma clase.
        """
        # Esta función simplemente devuelve la data limpia.
        return self.clean_data(use_categorical_vars=True)

    def _clean_data_wrapper_num(self, X, y=None):
        """
        Devuelve los datos limpios independientemente de la entrada, considerando 
        solo las columnas numéricas.

        Este método es un envoltorio que ignora cualquier entrada y proporciona
        una interfaz consistente para su uso en una pipeline de scikit-learn o
        transformadores similares que esperan una función con entradas X e y.

        Parámetros:
        ----------
        X : Este parámetro es ignorado.
        y : Ignorado, opcional (default=None)
            Este parámetro es ignorado.

        Retorna:
        -------
        pandas.DataFrame
            Un DataFrame que contiene los datos limpios obtenidos a través del
            método clean_data de la misma clase, considerando sólo las columnas numéricas.
        """
        # Esta función simplemente devuelve la data limpia.
        return self.clean_data(use_categorical_vars=False)
    
    
    # 5
    def scale(self, categorical_transformer=OneHotEncoder(sparse_output=False), use_categorical_vars = True):
        """
        Escala y transforma los datos numéricos y categóricos del conjunto de datos.

        Este método aplica una una codificación a las variables categóricas y luego transformación 
        logarítmica y una normalización Min-Max a todas las variables. La salida es un DataFrame 
        preparado para el modelado de machine learning.

        Parámetros:
        ----------
        categorical_transformer : transformer, opcional (default=OneHotEncoder(sparse_output=False))
            Un transformador que sigue la API de scikit-learn (debe tener los métodos 'fit' y 'transform').
            Se utiliza para transformar las variables categóricas. Por defecto, se utiliza OneHotEncoder.
        use_categorical_vars (bool): Indica si se deben utilizar las variables categóricas (por defecto, True).

        Retorna:
        -------
        pandas.DataFrame
            Un DataFrame con las características escaladas y las variables categóricas codificadas, si es que son 
            consideradas por use_categorical_vars.

        Levanta:
        ------
        ValueError
            Si el 'categorical_transformer' proporcionado no cumple con la API de scikit-learn (métodos 'fit' y 'transform').
        """
        #print("Aplicando scale")
        if not (hasattr(categorical_transformer, 'fit') and hasattr(categorical_transformer, 'transform')):
            raise ValueError("El algoritmo de transformación de variables categóricas proporcionado no es compatible con sklearn")
        
        scale_folder = os.path.join(self.output_folder, 'scale')
        os.makedirs(scale_folder, exist_ok=True)

        total_clean_data = self.clean_data(use_categorical_vars=use_categorical_vars)

        numerical_columns = total_clean_data.select_dtypes(include=[np.number]).columns.tolist()

        
        # Definimos el transformador para los datos numéricos
        numeric_transformer_pipeline = Pipeline(steps=[
            ('log1p', FunctionTransformer(np.log1p, validate=False)),
            ('scaler', MinMaxScaler())
        ])

        clean_data_transformer = FunctionTransformer(func=self._clean_data_wrapper, validate=False)
        if use_categorical_vars:
            categorical_columns = total_clean_data.select_dtypes(exclude=[np.number]).columns.tolist()
            # Definimos el transformador para los datos categóricos
            categorical_transformer_pipeline = Pipeline(steps=[
                ('cat', categorical_transformer),
                ('log1p', FunctionTransformer(np.log1p, validate=False)),
                ('scaler', MinMaxScaler())
            ])

            # Creamos el ColumnTransformer
            preprocessor = ColumnTransformer(
                transformers=[
                    ('cat', categorical_transformer_pipeline, categorical_columns), 
                    ('num', numeric_transformer_pipeline, numerical_columns),
                ]
            )
        else:
            #clean_data_transformer = FunctionTransformer(func=self._clean_data_wrapper_num, validate=False)
            # Creamos el ColumnTransformer
            preprocessor = ColumnTransformer(
                transformers=[
                    ('num', numeric_transformer_pipeline, numerical_columns),
                ]
            )


        # Creamos el Pipeline completo
        full_pipeline = Pipeline(steps=[
            ('clean_data', clean_data_transformer),  # Agrega el limpiador de datos al principio del pipeline
            ('preprocess', preprocessor)  # El resto del preprocesamiento como estaba antes
        ])



        # Obtenemos los nombres de las nuevas columnas generadas por el OneHotEncoder
        # Suponiendo que 'cat' es el nombre del paso en su pipeline de transformación categórica
        if use_categorical_vars:
            # Ajustamos el ColumnTransformer a los datos
            #preprocessor.fit(clean_data)
            #full_pipeline.fit(self.data)

            # Transformamos los datos con el ColumnTransformer
            #scaled_data = preprocessor.transform(clean_data)
            #scaled_data = full_pipeline.transform(self.data)
            scaled_data = full_pipeline.fit_transform(total_clean_data)
            categorical_feature_names = preprocessor.named_transformers_['cat']['cat'].get_feature_names_out(categorical_columns)
            # Combinamos los nombres de las columnas numéricas y categóricas
            new_column_names = np.concatenate((categorical_feature_names, numerical_columns))
        else:
            # Ajustamos el ColumnTransformer a los datos
            #preprocessor.fit(clean_data)
            #full_pipeline.fit(self.data.select_dtypes(include=[np.number]))

            # Transformamos los datos con el ColumnTransformer
            #scaled_data = preprocessor.transform(clean_data)
            #scaled_data = full_pipeline.transform(self.data.select_dtypes(include=[np.number]))
            scaled_data = full_pipeline.fit_transform(total_clean_data)
            new_column_names = numerical_columns


        # Creamos un DataFrame con los datos transformados y los nuevos nombres de columnas
        df_processed = pd.DataFrame(scaled_data, columns=new_column_names)

        df_processed.to_csv(f'{scale_folder}/scaled_features.csv', index=False)

        return df_processed
    
    def _scale_wrapper(self, X, y=None):
        """
        Devuelve los datos escalados independientemente de la entrada X.

        Este método es un envoltorio que ignora la entrada X y utiliza el método scale
        de la clase para devolver datos ya escalados. Está diseñado para ser compatible
        con las expectativas de entrada/salida de los componentes de scikit-learn como
        FunctionTransformer.

        Parámetros:
        ----------
        X : Ignorado
            Este parámetro es ignorado y no influye en el resultado.
        y : Ignorado, opcional (default=None)
            Este parámetro es ignorado y no se utiliza en el proceso.

        Retorna:
        -------
        pandas.DataFrame
            Retorna un DataFrame de los datos después de aplicar la función scale.
        """
        # Esta función devuelve la data escalada.
        
        return self.scale(use_categorical_vars=False)
    
    def _scale_wrapper_num(self, X, y=None):
        """
        Devuelve los datos escalados independientemente de la entrada X.

        Este método es un envoltorio que ignora la entrada X y utiliza el método scale
        de la clase para devolver datos ya escalados, considerando solo las columnas 
        numéricas. Está diseñado para ser compatible con las expectativas de 
        entrada/salida de los componentes de scikit-learn como FunctionTransformer.

        Parámetros:
        ----------
        X : Ignorado
            Este parámetro es ignorado y no influye en el resultado.
        y : Ignorado, opcional (default=None)
            Este parámetro es ignorado y no se utiliza en el proceso.

        Retorna:
        -------
        pandas.DataFrame
            Retorna un DataFrame de los datos después de aplicar la función scale, considerando
            solo las columnas numéricas.
        """
        # Esta función devuelve la data escalada.
        
        return self.scale(use_categorical_vars=False)
    # 6
    def make_clusters(self, clustering_algorithm = KMeans(n_init='auto'), n_clusters_range=(2, 12), plot_elbow=True, use_categorical_vars=False):
        """
        Realiza el análisis de clustering en los datos transformados por la clase. Esta función admite cualquier
        algoritmo de clustering de scikit-learn que sea una instancia de ClusterMixin. También puede determinar
        el número óptimo de clústeres si se solicita.

        Parámetros:
        clustering_algorithm : object, opcional (default=KMeans(n_init='auto'))
            El algoritmo de clustering para usar. Debe ser una instancia de ClusterMixin de scikit-learn.
            Por defecto, utiliza KMeans con una inicialización automática.
        
        n_clusters_range : tuple, opcional (default=(2, 12))
            Un rango de números de clusters a considerar si se está usando el método de codo para determinar
            el número óptimo de clusters. Esto será pasado al KElbowVisualizer.
        
        plot_elbow : bool, opcional (default=True)
            Si es True, la función buscará el número óptimo de clústeres utilizando el método de codo
            y lo graficará. Además, ajustará el algoritmo de clustering proporcionado con este número óptimo.
        use_categorical_vars (bool): Indica si se deben utilizar las variables categóricas (por defecto, False).

        Retorna:
        cluster_data : DataFrame
            Un DataFrame con los datos proyectados en 2 dimensiones principales y la asignación de clústeres.

        Levanta:
        ValueError
            Si el algoritmo de clustering proporcionado no es una instancia de ClusterMixin de scikit-learn.
        """
        #print("Aplicando make_clusters")
        # Comprobar si el algoritmo de clustering es una instancia de ClusterMixin para asegurar compatibilidad con sklearn
        if not isinstance(clustering_algorithm, ClusterMixin):
            raise ValueError("El algoritmo de clustering proporcionado no es compatible con sklearn")
        
        # Crear la carpeta para guardar los resultados de los clusters
        clusters_folder = os.path.join(self.output_folder, 'clusters')
        os.makedirs(clusters_folder, exist_ok=True)
        
        # Cargar y escalar los datos
        transformed_data = self.scale(use_categorical_vars=use_categorical_vars) 

        # Inicializar el número óptimo de clústeres con None
        optimal_n_clusters = None
        
        # Determinar el número óptimo de clústeres si es necesario y el algoritmo lo soporta
        if plot_elbow:
            elbow_model = KElbowVisualizer(clustering_algorithm, k=n_clusters_range)
            elbow_model.fit(transformed_data)
            elbow_model.show(outpath=os.path.join(clusters_folder, 'elbow_plot.png'))
            optimal_n_clusters = elbow_model.elbow_value_
            # Establecer el número óptimo de clústeres en el algoritmo
            clustering_algorithm.set_params(n_clusters=optimal_n_clusters)
        
        if use_categorical_vars:
            scale_transformer = FunctionTransformer(func=self._scale_wrapper, validate=False)
        else:
            scale_transformer = FunctionTransformer(func=self._scale_wrapper_num, validate=False)
         # Creamos el Pipeline completo
        full_pipeline = Pipeline(steps=[
            ('scale', scale_transformer), 
            ('clustering', clustering_algorithm) 
        ])
        # Ajustar el pipeline a los datos ya escalados
        #clusters = pipeline.fit_transform(transformed_data)
        labels = full_pipeline.fit_predict(transformed_data)

        # Proyectar los datos a 2 dimensiones para visualización
        decomposition = PCA(n_components=2)

        reduced_data = decomposition.fit_transform(transformed_data)
        
        # Crear un DataFrame para la visualización y guardar los resultados
        cluster_data = pd.DataFrame(reduced_data, columns=['PC1', 'PC2'])
        cluster_data['Cluster'] = labels

        # Crear un DataFrame y guardar los resultados
        cluster_data_with_all_cols = pd.DataFrame(transformed_data)
        cluster_data_with_all_cols['Cluster'] = labels
        cluster_data_with_all_cols.to_csv(os.path.join(clusters_folder, 'cluster_data.csv'), index=False)
        
        # Graficar los clústeres
        plt.figure(figsize=(10, 8))
        plt.scatter(cluster_data['PC1'], cluster_data['PC2'], c=cluster_data['Cluster'], cmap='viridis', marker='o')
        plt.title('Visualización de Clusters')
        plt.xlabel('PC 1')
        plt.ylabel('PC 2')
        # Creamos una lista de colores basados en los clusters únicos en 'labels'
        unique_labels = np.unique(labels)
        colors = plt.cm.viridis(np.linspace(0, 1, len(unique_labels)))

        # Creamos una lista de leyendas, una para cada cluster
        legend_handles = [Line2D([0], [0], marker='o', color='w', label=f'Cluster {label}',
                                markerfacecolor=color, markersize=10) for label, color in zip(unique_labels, colors)]

        # Añadimos la leyenda al gráfico con una ubicación específica fuera del área de trazado
        plt.legend(handles=legend_handles, title='Clusters', loc='upper left', bbox_to_anchor=(1,1))

        # Ajustar el layout para dar espacio a la leyenda fuera del gráfico
        plt.tight_layout()
        plt.savefig(os.path.join(clusters_folder, 'clusters_visualization.png'))
        plt.show()

        return cluster_data, cluster_data_with_all_cols
        
    # 7
    def detect_anomalies(self, algorithm = IsolationForest(n_jobs=-1)):
        """
        Detecta anomalías en el conjunto de datos utilizando el algoritmo de detección de 
        anomalías de scikit-learn especificado.

        Parámetros:
        algorithm : scikit-learn BaseEstimator (por defecto=IsolationForest(n_jobs=-1))
            El algoritmo de detección de anomalías a utilizar. Debe ser un estimador de 
            scikit-learn que soporte el método fit_predict..
        
        Retorna:
        numpy.ndarray
            Las etiquetas predichas para cada instancia en el conjunto de datos, donde -1 indica 
            una anomalía y 1 indica un valor normal.

        Levanta:
        ValueError: Si el algoritmo proporcionado no es un estimador de scikit-learn válido.
        """
        #print("Aplicando detect_anomalies")
        # Verificar que el algoritmo pertenezca a sklearn
        if not issubclass(type(algorithm), BaseEstimator):
            raise ValueError("El algoritmo proporcionado no es un estimador de scikit-learn válido.")

        # Crear carpeta para anomalies
        path_anomalies = os.path.join(self.output_folder, 'anomalies')
        os.makedirs(path_anomalies, exist_ok=True)

        # Preprocesar y escalar los datos
        preprocessed_scaled_data_original = self.scale()
        preprocessed_scaled_data = preprocessed_scaled_data_original.copy()

        # Crear el pipeline con solo el algoritmo de detección de anomalías
        scale_transformer = FunctionTransformer(func=self._scale_wrapper, validate=False)

        pipeline = Pipeline(steps=[
            ('scale', scale_transformer), 
            ('anomaly_detector', algorithm) 
        ])

        scores =  pipeline.fit_predict(preprocessed_scaled_data)

        # Apply PCA
        decomposition = PCA(n_components=2)
        data_2d = decomposition.fit_transform(preprocessed_scaled_data)

        # Usar colores específicos para -1 y 1.
        colors = np.where(scores == -1, 'red', 'blue')  # 'red' para -1, 'blue' para 1.

        # Plotting the results
        plt.scatter(data_2d[:, 0], data_2d[:, 1], c=colors)

        # Crear handles personalizados
        legend_elements = [Line2D([0], [0], marker='o', color='w', label='Data Anomala',
                                markerfacecolor='red', markersize=10),
                        Line2D([0], [0], marker='o', color='w', label='Data Normal',
                                markerfacecolor='blue', markersize=10)]

        # Crear la leyenda con los handles personalizados
        plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc='upper left')

        plt.title('Detección de Anomalías')
        plt.xlabel('PC 1')
        plt.ylabel('PC 2')

        # Asegurarse de que el layout se ajuste para no cortar la leyenda
        plt.tight_layout()
        plt.savefig(os.path.join(path_anomalies, 'anomaly_detection.png'))


        # Agregar etiquetas de anomalías al DataFrame y guardar
        data_with_anomalies = preprocessed_scaled_data
        data_with_anomalies['anomaly_label'] = scores
        data_with_anomalies.to_csv(os.path.join(path_anomalies, 'data_anomalies.csv'), index=False)

        return scores

    
    #8
    def profile(self, variables_of_interest_summarize=None, criteria_for_outliers=None, 
                variables_of_interest_plot=None, top_n_categories=5, 
                use_categorical_vars_clean=True,
                variables_of_interest_clean_data=None, 
                drop_duplicates=True, 
                drop_na=False, 
                impute_na=True, 
                numeric_cols = ['age', 'height', 'weight'], 
                scaling_technique = OneHotEncoder(sparse_output=False), 
                scale_categorical_vars = True,
                clustering_algorithm = KMeans(n_init='auto'), 
                cluster_categorical_vars = False,
                n_clusters_range = (2, 12), 
                plot_elbow = True, 
                anomaly_detection_algorithm=IsolationForest(n_jobs=-1)):
        """
        Realiza un análisis de perfil completo del conjunto de datos, incluyendo resumen, 
        detección de outliers, visualizaciones, limpieza de datos, escalado, clustering y 
        detección de anomalías.

        Parámetros:
        ----------
        variables_of_interest_summarize : list of str, opcional
            Variables a resumir en el método summarize.
        criteria_for_outliers : dict, opcional
            Criterios específicos para identificar outliers en el método summarize.
        variables_of_interest_plot : list of str, opcional
            Variables a visualizar en el método plot_vars.
        top_n_categories : int, default=5
            Top N categorías a mostrar en las visualizaciones de variables categóricas.
        use_categorical_vars_clean : Indica si se deben utilizar las variables categóricas en el clean_data (por defecto, True).
        variables_of_interest_clean_data : list of str, opcional
            Variables a incluir en el proceso de limpieza de datos.
        drop_duplicates : bool, default=True
            Si se deben eliminar duplicados en el método de limpieza de datos.
        drop_na : bool, default=True
            Si se deben eliminar las filas con valores NA en el método de limpieza de datos.
        impute_na : bool, default=False
            Si se deben imputar los valores NA en el método de limpieza de datos.
        numeric_cols : list of str, default=['age', 'height', 'weight']
            Columnas numéricas a considerar en el proceso de escalado.
        scaling_technique : transformer, default=OneHotEncoder(sparse_output=False)
            Técnica de escalado para aplicar a los datos antes de la clusterización.
        scale_categorical_vars : Indica si se deben utilizar las variables categóricas en el scale (por defecto, True). 
        clustering_algorithm : clustering instance, default=KMeans(n_init='auto')
            Algoritmo de clustering para usar en la generación de clústeres.
        cluster_categorical_vars : Indica si se deben utilizar las variables categóricas en el make_clusters (por defecto, False). 
        n_clusters_range : tuple, default=(2, 12)
            Rango de número de clústeres a considerar para el método 'make_clusters'.
        plot_elbow : bool, default=True
            Si se debe generar o no el gráfico del codo para ayudar a determinar el número óptimo de clústeres.
        anomaly_detection_algorithm : anomaly detection instance, default=IsolationForest(n_jobs=-1)
            Algoritmo para la detección de anomalías en el conjunto de datos.

        Retorna:
        -------
        tuple
            Una tupla que contiene los resultados de los siguientes procesos:
            - Resumen de estadísticas descriptivas
            - Visualización de variables
            - Datos limpios
            - Datos escalados
            - Clústeres generados
            - Anomalías detectadas
        """
        #print("Aplicando profile")
        # Ejecutar el método summarize
        summ = self.summarize(variables_of_interest=variables_of_interest_summarize, criteria_for_outliers=criteria_for_outliers)
        
        # Limpiar los datos
        clean_data = self.clean_data(variables_of_interest=variables_of_interest_clean_data, drop_duplicates=drop_duplicates, 
                                     drop_na=drop_na, impute_na=impute_na, numeric_cols=numeric_cols, use_categorical_vars = use_categorical_vars_clean)
        
        # Ejecutar el método plot_vars
        plt_vars = self.plot_vars(data=clean_data ,variables_of_interest=variables_of_interest_plot, top_n_categories=top_n_categories)
        
        # Escalar los datos
        scaled_data = self.scale(categorical_transformer=scaling_technique, use_categorical_vars = scale_categorical_vars)
        
        # Ejecutar clustering
        clusters = self.make_clusters(clustering_algorithm=clustering_algorithm, 
                                      n_clusters_range=n_clusters_range, 
                                      plot_elbow=plot_elbow, 
                                      use_categorical_vars=cluster_categorical_vars)

        # Detectar anomalías
        anomalies = self.detect_anomalies(anomaly_detection_algorithm)

        return summ, plt_vars, clean_data, scaled_data, clusters, anomalies



    # 9
    def clearGarbage(self):
        """
        Elimina todas las carpetas y archivos creados por la clase Profiler. 
        """
        print("Aplicando clearGarbage")
        if os.path.exists(self.output_folder):
            shutil.rmtree(self.output_folder)

# %%
profiler = Profiler(df)  

summ, plt_vars, clean_data, scaled_data, clusters, anomalies = profiler.profile()

# %%
#profiler.clearGarbage()

# %% [markdown]
# ## 1.2 Caracterizar datos de Olimpiadas (2.0 puntos)
#
# A partir de la clase que hemos desarrollado previamente, procederemos a realizar un análisis exhaustivo de los datos proporcionados en el enunciado. Este análisis se presentará en forma de un informe contenido en el mismo Jupyter Notebook y abordará los siguientes puntos:
#
# 1. Introducción
#     - Se proporcionará una breve descripción del problema que estamos abordando y se explicará la metodología que se seguirá.
#
# Elaborar una breve introducción con todo lo necesario para entender qué realizarán durante su proyecto. La idea es que describan de manera formal el proyecto con sus propias palabras y logren describir algunos aspectos básicos tanto del dataset como del análisis a realizar sobre los datos.
#
# Por lo anterior, en esta sección ustedes deberán ser capaces de:
#
# - Describir la tarea asociada al dataset.
# - Describir brevemente los datos de entrada que les provee el problema.
# - Plantear hipótesis de cómo podrían abordar el problema.
#
# 2. Análisis del EDA (Análisis Exploratorio de Datos)
#     - Se discutirán las observaciones y conclusiones obtenidas acerca de los datos proporcionados. A lo largo de su respuesta, debe responder preguntas como:
#         - ¿Como se comportan las variables numéricas? ¿y las categóricas?
#         - ¿Existen valores nulos en el dataset? ¿En qué columnas? ¿Cuantos?
#         - ¿Cuáles son las categorías y frecuencias de las variables categóricas?
#         - ¿Existen datos duplicados en el conjunto?
#         - ¿Existen relaciones o patrones visuales entre las variables?
#         - ¿Existen anomalías notables o preocupantes en los datos?
# 3. Creación de Clusters y Anomalías
#     - Se justificará la elección de los algoritmos a utilizar y sus hiperparámetros. En el caso de clustering, justifique además el número de clusters.
#
# 4. Análisis de Resultados
#     - Se examinarán los resultados obtenidos a partir de los clústers y anomalías generadas. ¿Se logra una separación efectiva de los datos? Entregue una interpretación de lo que representa cada clúster y anomalía.
# 5. Conclusión
#     - Se resumirán las principales conclusiones del análisis y se destacarán las implicaciones prácticas de los resultados obtenidos.

# %% [markdown]
# ### 1. Introducción
#
# El problema a resolver consiste en la caracterización de los datos generados por los Juegos Panamericanos desarrollados en el país entre el 20 de octubre y el 5 de noviembre de 2023. La idea es realizar una clase que permita caracterizar estos datos de forma automática y eficiente para su correcto análisis posterior, sin necesidad de preparar o trabajar los datos antes de ingresarlos a la clase.
#
# Para probar el funcionamiento de la clase durante su construcción, se proporcionó una base de datos con data de distintos juegos olímpicos pasados. Sin embargo, la idea es que esta clase funcione con cualquier dataset, por lo que resulta sumamente importante a la hora de su construcción que el código sea lo más agnóstico a los datos provistos posible.
#
# Los datos provistos sobre juegos olímpicos pasados corresponden a entradas de distintos participantes de estos juegos. En este sentido, cada fila del dataset indica tanto características de los deportistas participantes, como los son el nombre, sexo, edad, altura y peso. Además, en la misma fila se incluye al país y equipo al que representa el deportista, junto con los juegos en los que compitió, con la ciudad en la que lo hizo, el deporte en el que participó, el evento, y finalmente el tipo de medalla que obtuvo (en caso de obtener medalla). Cabe destacar que las columnas correspondientes a la edad, el peso y la altura no venían como tres columnas separadas en el dataset original, si no que las tres venían contenidas en una columna no atómica. Sin embargo este tema se abordará más adelante en el informe.
#
# Para abordar este problema se plantea la creación de la clase Profiler, junto con nueve métodos que permitan caracterizar correctamente los datos:
#
# 1. Constructor: este método recibe los datos a trabajar para automáticamente crear una carpeta en el directorio con la fecha en que se está ejecutando el programa.
# 2. Summarize: este método toma como entrada los datos, una lista con las variables que son de interés y una tupla para la identificación de outliers, y genera un archivo .txt con un resumen de las estadísticas y características de las variables en los datos. En este sentido, se generan características sobre los tipos de variables, valores únicos, valores nulos, estadísticas descriptivas, etc.
# 3. Plot_vars: este método toma como entrada los datos, variables de interes y el número top de categorías a graficar. Su función es crear visualizaciones para las variables numéricas, como lo son los gráficos de correlación y los gráficos de distribución de densidad. Al mismo tiempo, para las variables categóricas genera un gráfico del coeficiente V de Cramer entre las variables, y también histogramas con las top categorías.
# Todos estos gráficos son almacenados en una carpeta llamada plots dentro de la generada por el constructor.
# 4. Clean_data: este método toma como entrada los datos, una lista de variables de interés, y distintas configuraciones que se pueden hacer para configurar la limpieza de los datos. En este sentido, se puede indicar la eliminación de valores duplicados, la eliminación de valores nulos y la imputación de valores nulos. Entonces además de las funcionalidades anteriormente mencionadas, este método también es capaz de detectar aquellas columnas que sean no atómicas, y una vez detectadas, también es capaz de separarla en las columnas que la compongan. Finalmente guarda los datos transformados dentro de la carpeta clean_data dentro de la misma carpeta creada por el constructor.
# 5. Scale: este método toma como entrada los datos y el tipo de escalamiento que se le quiere realizar a los datos categóricos. En este sentido, el método utiliza un escalador logarítmico y un MinMaxScaler para escalar los datos numéricos, mientras que utiliza OneHotEncoder, o el algoritmo a elección, para el escalamiento de los datos categóricos. Finalmente guarda los datos escalados en la carpeta scale creada dentro de la carpeta generada por el constructor.
# 6. Make_clusters: este método toma como entrada el algoritmo de clustering a utilizar, junto con un rango de número de clusters y la opción de que se utilice el método del codo para la optimización del número de clusters a elegir. En este sentido, el método es capaz de generar clusters óptimos para cualquier tipo de datos, ya que además utiliza el método scale, y a través de un pipeline genera los clusters para posteriormente mediante el uso PCA generar un gráfico de los clusters en cuestión. Finalmente este gráfico es guardado en la carpeta clusters_folder dentro de la ya creada automaticamente por el constructor.
# 7. Detect_anomalies: este método toma como entrada un algoritmo de Sklearn para la detección de anomalías. En este sentido, se genera un pipeline donde primeramente se preprocesan los datos con el uso de algunos de los métodos anteriores, y se generan etiquetas al ajustar el algoritmo de detección de anomalías elegido. Finalmente, mediante PCA se grafican los datos distinguiendolos entre anómalos y no anómalos para su comparación. Este gráfico es guardado en la carpeta anomalies dentro de la carpeta creada previamente por el constructor.
# 8. Profile: este método ejecuta todos los métodos anteriores.
# 9. ClearGarbage: este método elimina todos los archivos creados por el uso de los métodos de Profiler.
#
# Con esta clase se espera poder caracterizar correctamente los datos de los Juegos Panamericanos a desarrollarse en el país.
#
# ### 2. Análisis del EDA
#
# A partir de los datos de prueba de Juegos Olímpicos anteriores, se realiza un análisis exploratorio de datos con la clase Profiler y sus métodos summarize y plot_vars. A summarize no se le entregó una tupla para detección de outliers, ya que esta función está pensada para columnas en específico y no para todos los datos. Por otro lado, el método clean_data está configurado para eliminar los valores duplicados e imputar los valores nulos. Finalmente plot_vars tiene por defecto la variable top_n_categories = 5, por lo que los gráficos de las variables categóricas mostrarán las top 5 categorías.
# Cabe destacar que los datos con los que se corrió la clase corresponde a una fracción de los datos totales debido al elevado tiempo de compilación de los métodos de la clase con los datos completos.
#
# Entonces, viendo el archivo entregado por summarize sobre los datos crudos, es posible notar que la variable ID, que corresponde a los identificadores únicos de los atletas, se repiten en varias ocasiones, lo que indica que un mismo atleta puede participar en más de una competencia o en más de un solo Juego Olímpico. Junto con esto, se ve que hay un total de 15554 atletas únicos, mientras que hay 16944 observaciones en el dataset. Además, no tiene valores nulos ni valores cero.
#
# Con respecto a la columna name, esta condice lo visto en la columna anterior, aunque hay un número menor de valores únicos con 15538. Esto puede llevar a pensar que existe una diferencia entre los IDs y los nombres de los deportistas, lo que puede deberse a que el nombre de algún deportista esté redactado de forma distinta entre entradas, o que existan diferentes IDs para un mismo nombre. Esta columna no posee valores nulos.
#
# La columna sex, que indica si el atleta corresponde al sexo masculino o femenino tiene dos tipos de valores únicos y no posee valores nulos. Su gráfico indica que el sexo masculino es poco más del cuadruple en cantidad de entradas en el dataset por sobre el femenino.
#
# La columna team que corresponde al equipo al que representa el atleta, posee 460 valores únicos y 0 valores nulos. Su gráfico indica que la mayoría de las entradas del dataset compiten por el equipo de EEUU, Francia, Gran Bretaña, Italia y Alemania.
#
# La columna NOC, que indica el país originario del atleta, posee 215 valores únicos y 0 valores nulos. Con respecto a su gráfico, se puede ver lo mismo que en la columna anterior, ya que ambas estan relacionadas. En orden descendente están EEUU, Frnacia, Gran Bretaña, Italia y Alemania.
#
# La columna games, que indica a qué juegos olímpicos corresponde la entrada, tiene 51 valores únicos y 0 valores nulos. Con respecto a su gráfico, se ve que no existe gran diferencia, pero en orden descendente están los JJOO 2000 Verano, 1996 Verano, 2008 Verano, 2004 Verano y 1992 Verano.
#
# La columna year, que indica el año en que se desarrolla la competencia de la entrada, se ve que hay 35 valores únicos, y ningún valor 0 ni nulos. Además se nota que el registro más antiguo corresponde al año 1896, mientras que el más reciente es del 2016.
# El gráfico de densidad indica que a medida que los años se acercan a la actualidad, existen más registros de participaciones en los juegos.
#
# La columna season indica si el registro se refiere a los juegos olímpicos de invierno o de verano. En este sentido, se tienen solamente dos valores únicos y no existen nulos. Además, al ver su gráfico es posible notar que la mayoría de los registros corresponden a los JJOO de verano.
#
# La columna city indica la ciudad en la que se desarrolló la competencia. Esta posee 42 valores únicos y ningún valor nulo. Con respecto a su gráfico, se ve que en orden descendiente las ciudades con más registros son London, Athina, Sydney, Atlanta y Beijing.
#
# La columna sport indica el deporte al que corresponde el registro. Existe un total de 61 valores únicos en esta columna con ningún valor nulo. Con respecto a su gráfico, se ve que los deportes con más registros son Athletics, Swimming, Gymnastics, Shooting y Fencing.
#
# La columna event indica el evento del deporte al que corresponde el registro. En esta columna se tienen 665 registros únicos sin valores nulos.
# Su gráfico indica que los eventos con más registros son Football Men's Football, Hockey Men's Hockey, Ice Hockey Men's Ice Hockey, Water Polo Men's Water Polo, Basketball Men's Basketball.
#
# La columna medal, indica el tipo de medalla que recibio el atleta en caso de recibir medalla. Aquí existen 3 valores únicos correspondientes a los tres tipos de medallas. El problema que puede generar esta columna es que si un atleta no recibió una medalla, entonces presenta un valor nulo. Es por esto que al imputar los datos, se cambia los valores nulos por la variable mayoritaria, que en este caso es la medalla de oro. Es por esto que al ver el gráfico se ve que hay muchos medallistas de oro. Una forma de solucionar esto es cambiar la configuración del método clean_data de manera que se eliminen los nulos y no se imputen los datos. De esta manera se obtendría un dataset que contenga solamente a los medallistas, lo cual también podría ser interesante de analizar.
#
# La columna age-height-weight es una columna no atómica que contiene los valores de las columnas age, height y weight. Esta columna debió ser trabajada en el método clean_data, por lo que se pudo obtener los gráficos individuales de cada una de estas variables.
# La variable age, indica la edad del atleta al momento de la competición. Su gráfico de densidad se podría asimilar a simple vista como una distribución normal donde la mayoría de los datos están entre los 20 y los 30 años.
# La variable height indica la altura de los atletas. Su gráfico también pareciera ser una distribución normal. En este caso la mayoría de los datos están entre los 170 y los 190 cm de altura.
# La variable weight indica el peso de los atletas. Su gráfico indica que la mayoría se encuentra entre los 70 y los 80 kg de peso.
#
# Luego, viendo el gráfico de correlación de las variables numéricas, es posible notar que existe una sola correlación sobre 0.5, correspondiente a height y weight con un valor de 0.77. Esto indica que aquellos atletas que son más altos tienden a pesar más y viceversa. Lo cual intuitivamente tiene sentido.
#
# Finalmente, viendo el gráfico de la matriz de Cramer para las variables categóricas, es posible notar que la variables Sex y Event; Team y NOC; Season y City con Games; City, Sport y Event con Season; y finalmente Event con Sport están fuertemente asociadas entre sí.
#
# ### 3. Creación de clusters y anomalías
#
# En esta sección, se abordará la aplicación de los métodos de clustering y detección de anomalías, para esto primero se debe destacar la estrategia de sampleo utilizada donde se ha seleccionado 1/16 de los datos totales. Este enfoque permitirá explorar con detalle la creación de clusters y la detección de anomalías, manteniendo un equilibrio entre precisión y eficiencia computacional. Además, se debe tener en cuenta que para el escalamiento de los datos categóricos se utilizó OneHotEncoder, el cual genera más columnas para cada una de las opciones, esto decisión se debe a que se trabaja bajo al supuesto de que no hay variables categóricas ordinales, por lo que solo se diferencian las distintas opciones en cada columna sin un orden específico.
#
# Para clusterización, se plantea el uso de Kmeans de los datos, sin considerar las variables categóricas. En este sentido, el código del método make_clusters permite la identificación automática del número de clusters óptimo. Junto con esto, Kmeans es un algoritmo que es computacionalmente eficiente, además de que es capaz de manejar grandes conjuntos de datos, como el que se tiene. Así, el gráfico del método del codo y de los clusters (PCA) se pueden ver de la siguiente forma:
#
# <div style="display: flex; justify-content: space-between; align-items: flex-end;">
#     <div style="width: 49%; text-align: center; display: flex; flex-direction: column; justify-content: flex-end;">
#         <img src=".\EDA_10-11-2023_sample_16\clusters\elbow_plot.png" alt="Gráfico del Método del Codo" style="width: 800px; height: 500px;" />
#         <p>Gráfico del Método del Codo para Determinar el Número Óptimo de Clusters</p>
#     </div>
#     <div style="width: 49%; text-align: center; display: flex; flex-direction: column; justify-content: flex-end;">
#         <img src=".\EDA_10-11-2023_sample_16\clusters\clusters_visualization.png" alt="Visualización de Clusters" style="width: 800px; height: 500px;" />
#         <p>Visualización de Clusters Utilizando PCA</p>
#     </div>
# </div>
#
# #### Método del Codo:
# La gráfica del método del codo muestra una disminución pronunciada en la puntuación de distorsión a medida que aumenta el número de clusters hasta k=5, punto en el cual la reducción en la puntuación de distorsión se vuelve menos marcada. Esto indica que k=5 es el punto óptimo para el número de clusters, ya que agregar más clusters no mejora significativamente la suma de las distancias al cuadrado dentro de los clusters. El "codo" se encuentra en k=5 con una puntuación de distorsión de aproximadamente 503.547, número que se utiliza para la generación de clusters finales y su visualización.
#
# #### Visualización de Clusters:
# La gráfica de dispersión de PCA muestra cinco clusters diferenciados por colores. Se observa que:
#
# El Cluster 0 (color púrpura) tiene puntos que están en su mayoría agrupados en torno al origen en PC1 pero dispersos a lo largo de PC2.
# El Cluster 1 (color azul) se extiende a lo largo del eje de PC1 con una dispersión moderada en PC2.
# El Cluster 2 (color verde) parece tener una dispersión similar al Cluster 1 pero en una posición diferente en el plano de PC1 y PC2.
# El Cluster 3 (color amarillo) está altamente concentrado cerca del origen en PC1, con una ligera dispersión a lo largo de PC2.
# El Cluster 4 (color naranja) tiene puntos que están mayormente contenidos en una región específica del gráfico.
# Estos patrones sugieren que los datos se pueden segmentar naturalmente en cinco grupos distintos, con cada cluster representando posiblemente diferentes características intrínsecas en los datos.
#
# #### Consideraciones en el Clustering
# El algoritmo Kmeans se ha aplicado considerando únicamente las variables numéricas, debido a que los métodos de clustering basados en distancias euclidianas, como Kmeans, tienden a tener un rendimiento inferior cuando se incluyen variables categóricas. Esta decisión se basa en el entendimiento de que las distancias euclidianas no son tan efectivas para medir similitudes entre datos categóricos. Las variables numéricas fueron escaladas utilizando un escalado logarítmico y luego un minmaxscaler de manera secuencial.
#
# La implementación del método make_clusters incluye la opción de visualización del método del codo, que es una herramienta esencial para determinar el número óptimo de clusters. La gráfica resultante del método del codo, junto con la visualización de los clusters mediante un análisis de componentes principales (PCA), ofrece una comprensión clara de la estructura de los datos y la cohesión dentro de cada cluster.
#
# Las figuras resultantes del proceso ilustran que el número óptimo de clusters, según el método del codo, está bien definido, lo que indica una agrupación clara y significativa en el conjunto de datos. Además, la visualización de los clusters a través de PCA permite una interpretación intuitiva de la distribución y separación de los grupos en un espacio bidimensional, facilitando así la identificación de patrones y posibles anomalías en los datos.
#
#
# #### Anomalías:
#
# <div style="display: flex; justify-content: space-between; flex-direction: column; align-items: center;">
#     <img src=".\EDA_10-11-2023_sample_16\anomalies\anomaly_detection.png" alt="Detección de anomalías" width="600" />
#     <p>Detección de anomalías</p>
# </div>
#
#
# Se utilizó el algoritmo IsolationForest de scikit-learn para la detección de anomalías. Este algoritmo es adecuado para manejar datos de alta dimensión y es eficiente en términos de tiempo de cálculo. Se configuró con n_jobs=-1 para utilizar todos los procesadores disponibles y acelerar el procesamiento, además se dejaron el resto de parámetros por default como max_samples y contamination ya que no se tiene información a priori de la cantidad de anomalías presentes en los datos.
#
# Los datos categóricos se transformaron usando OneHotEncoder, seguido de un escalamiento logarítmico y luego MinMaxScaler que también se utilizó para las variables numéricas. Este enfoque se eligió considerando que no se trataba con variables categóricas ordinales y para normalizar tanto los códigos generados como las variables numéricas.
#
# La función detect_anomalies implementa el proceso de detección. Primero, se verifica que el algoritmo sea un estimador válido de scikit-learn. Luego, se preprocesan y escalan los datos. El pipeline se configura solo con el algoritmo de detección de anomalías.
#
# Se aplica PCA para reducir la dimensionalidad a dos componentes, facilitando la visualización. Las anomalías detectadas se representan en un gráfico de dispersión, donde los puntos rojos indican anomalías y los azules valores normales.
#
# Las etiquetas de anomalías, donde -1 indica una anomalía y 1 un valor normal, se agregan al DataFrame y se guardan en un archivo CSV. Esto permite un análisis detallado y el seguimiento de las anomalías detectadas.
#
# El uso de IsolationForest junto con un adecuado preprocesamiento y escalamiento de los datos permite una eficaz detección de anomalías en el conjunto de datos. La visualización a través de PCA ofrece una interpretación clara y directa de las anomalías detectadas, facilitando la identificación de patrones inusuales o preocupantes en los datos.
#
# Este enfoque proporciona una herramienta valiosa para entender mejor y depurar el conjunto de datos, identificando posibles errores, valores atípicos o instancias inusuales que podrían necesitar una investigación adicional.

# %%
import pandas as pd
# Rutas a los archivos CSV
ruta_anomalies = r'.\EDA_10-11-2023_sample_16\anomalies\data_anomalies.csv'
ruta_clusters = r'.\EDA_10-11-2023_sample_16\clusters\cluster_data.csv'

# Leer los archivos CSV en DataFrames
df_anomalies = pd.read_csv(ruta_anomalies)
df_clusters = pd.read_csv(ruta_clusters)

# %%
# df_clusters, columna 'Cluster' para las etiquetas de clúster
cluster_groups = df_clusters.groupby('Cluster')

# Perfil de Clúster
cluster_summary = cluster_groups.describe()  

print("Perfil de Clúster")
print(cluster_summary)
cluster_summary.to_csv('cluster_summary.csv',index=False)


# Comparación con el Total
overall_summary = df_clusters.describe() 

print("Comparación con el Total")
print(overall_summary)
overall_summary.to_csv('overall_summary.csv', index=False)

# Análisis de Variables Individuales utilizando histplot e
for column in df_clusters.columns[:-1]:  # Excluye la columna 'Cluster'
    plt.figure(figsize=(10, 4))
    for cluster in cluster_groups.groups:
        sns.histplot(cluster_groups.get_group(cluster)[column], kde=True, label=f'Cluster {cluster}')
    plt.title(f'Distribución de {column} por Clúster')
    plt.legend()
    plt.savefig(f'distribution_{column}_by_cluster.png')
    plt.show()
    plt.close()
# Out:
# Perfil de Clúster
#               ID                                                              \
#            count      mean       std       min       25%       50%       75%
# Cluster
# 0         2927.0  0.926488  0.030394  0.580997  0.930199  0.930199  0.930199
# 1         2877.0  0.902275  0.091667  0.132930  0.858638  0.931552  0.970948
# 2         6608.0  0.931727  0.053426  0.768205  0.896135  0.944014  0.976957
# 3        11522.0  0.925602  0.046327  0.620991  0.930199  0.930199  0.938763
# 4         1599.0  0.693940  0.113246  0.000000  0.644674  0.726971  0.771851
#
#                       Year            ...    height             weight  \
#               max    count      mean  ...       75%       max    count
# Cluster                               ...
# 0        0.930199   2927.0  0.693149  ...  0.507077  0.628961   2927.0
# 1        0.999964   2877.0  0.255667  ...  0.576010  0.788531   2877.0
# 2        1.000000   6608.0  0.902146  ...  0.576010  0.576010   6608.0
# ...

# %% [markdown]
# ### 4. Análisis de Resultados
#
# #### Clusters
# Las imágenes generadas muestran las distribuciones de diferentes variables (edad, altura, ID, peso y año) por clúster. A continuación, se interpretarán estos resultados.
#
# En base a las gráficas de distribución:
#
# - Edad y Peso: Las distribuciones de edad y peso son bastante similares entre los clústeres, indicando que estos atributos podrían no ser los principales diferenciadores entre los clústeres. Sin embargo, hay picos y variaciones menores que sugieren algunas diferencias, posiblemente debido a subgrupos dentro de los clústeres.
# - Altura y Año: Estas variables muestran diferencias más claras entre algunos clústeres, lo que sugiere que han contribuido más significativamente a la formación de clústeres. Por ejemplo, hay clústeres donde las alturas o los años están agrupados en rangos específicos, lo que indica una posible separación efectiva basada en estas características.
#
# Interpretación de lo que representa cada clúster:
#
# - Clúster 0: Podría representar una categoría general con una amplia gama de edades y pesos. La altura y el año también tienen una distribución amplia, sugiriendo que este clúster puede incluir una variedad de participantes sin un rasgo distintivo particular.
#
# - Clúster 1: Este clúster tiene distribuciones más estrechas para algunas variables, lo que podría indicar un grupo más homogéneo de participantes en términos de altura o año de participación.
#
# - Clúster 2: Parece tener una variabilidad baja en altura y peso, lo que sugiere que podría estar formado por participantes con características físicas similares.
#
# - Clúster 3 y 4: Estos clústeres tienen picos muy marcados en las distribuciones de algunas variables, lo que podría indicar subgrupos muy específicos de participantes, como aquellos que compitieron en ciertos años o que tienen atributos físicos particulares.
#
# En particular
#
# - Clúster 0
# Miembros: 2927
# Año: Media de aproximadamente 0.693.
# Altura: Media de 0.507 lo que sugiere un grupo con menor altura.
# Peso: Media de 0.387 sugiere un grupo más ligero.
#
# - Clúster 1
# Miembros: 2877
# Año: Media de 0.255, la cual es significativamente más baja que la del Clúster 0, lo que podría sugerir un rango de años anterior.
# Altura y Peso: Medias más altas que en el Clúster 0, lo que indica que este grupo podría ser físicamente más grande.
#
# - Clúster 2
# Miembros: 6608
# Año: Media más alta, lo que podría indicar participantes más recientes.
# Altura y Peso: Medias muy similares al Clúster 1.
#
# - Clúster 3
# Miembros: 11522
# Año: Media ligeramente menor que en el Clúster 2, indicando un rango de años posiblemente más amplio.
# Altura y Peso: Medias más altas, lo que sugiere que este clúster podría contener los individuos más altos y pesados.
#
# - Clúster 4
# Miembros: Resto
# Año: Media más alta, indicando posiblemente años más recientes.
# Altura y Peso: Media del peso similar a otros clústeres pero con una desviación estándar mayor, lo que indica mayor variabilidad en el peso.

# %%
summary = anomalies.describe()
print(summary)
summary.to_csv('anomalies_summary.csv', index=False)
# Out:
#        Name_ Eleonora Margarida Josephina Scmitt  Name_ Th Anh  \
# count                                     2620.0        2620.0
# mean                                         0.0           0.0
# std                                          0.0           0.0
# min                                          0.0           0.0
# 25%                                          0.0           0.0
# 50%                                          0.0           0.0
# 75%                                          0.0           0.0
# max                                          0.0           0.0
#
#        Name_ Th Ngn Thng  Name_A. Darnis  Name_A. Lawry  Name_A. Wynne Rogers  \
# count             2620.0     2620.000000         2620.0                2620.0
# mean                 0.0        0.000382            0.0                   0.0
# std                  0.0        0.019537            0.0                   0.0
# min                  0.0        0.000000            0.0                   0.0
# ...

# %% [markdown]
# #### Anomalías
#
#
# El gráfico de Detección de anomalías se muestran los resultados de un análisis de detección de anomalías ejecutado en el sampleo de 1/16 del conjunto de datos. Utilizando el algoritmo IsolationForest de scikit-learn, se asignaron etiquetas a las instancias de los datos, donde los valores atípicos se marcan como anomalías (en rojo) y los valores normales (en azul). La representación en dos dimensiones fue lograda mediante el uso de Análisis de Componentes Principales (PCA), que es una técnica común para reducir la dimensionalidad de los datos, facilitando así su visualización y comprensión.
#
# Se observa que las anomalías se encuentran dispersas y no siguen un patrón agrupado como los datos normales, indicando que el algoritmo ha identificado correctamente puntos que se desvían del comportamiento típico del conjunto de datos. Los datos normales parecen estar agrupados en distintas concentraciones, lo que sugiere patrones o subgrupos dentro de los datos normales.
#
# Cada anomalía representada en rojo podría indicar un comportamiento atípico o una instancia que no sigue el patrón de los datos más generales. La eficacia de la separación entre datos normales. En este caso, parece que hay una separación efectiva, ya que las anomalías están claramente distanciadas de los principales grupos de datos normales.
#
# En particular parece que las anomalías no se agrupan en un sector en específico ni comparten características generales ya que tienen una media cercana a 0.5 en las variables numéricas, por lo que parece que una anomalía esta dada por una desviación en una o más características respecto a los datos normales y no a una agrupación de datos anómalos, como sabemos que los datos normales se pueden agrupar en clusters que ya definimos, podemos comparar las anomalías con los clusters para tener una mejor visión de como son.
#
# Los valores medios para las anomalías son los siguientes:
#
# - Año: 0.643, lo que podría sugerir que las anomalías no están concentradas en un periodo específico y podrían distribuirse uniformemente a lo largo del tiempo o centrarse ligeramente en años más recientes, pero no tan recientes como algunos de los clústeres.
# - Altura: 0.563, lo que indica una estatura media en el contexto de los datos.
# - Peso: 0.514, que es un peso medio.
#
# Comparando estos valores con las descripciones de los clústeres se puede decir que:
#
# - El valor medio del año para las anomalías es menor que el del Clúster 2 y Clúster 4, pero más alto que el del Clúster 1. Esto podría sugerir que las anomalías tienden a no estar tan concentradas en los años más recientes como los miembros del Clúster 2 y Clúster 4, pero son más recientes que los del Clúster 1.
# - La altura media de las anomalías está entre los valores del Clúster 0 y Clúster 1, lo que sugiere que las anomalías no son tan bajas como el Clúster 0 ni tan altas como el Clúster 1.
# - El peso medio de las anomalías es mayor que el del Clúster 0 pero menor que el de los Clústeres 1, 2 y 3. Esto indica que las anomalías podrían no ser tan ligeras como el grupo más ligero (Clúster 0), pero tampoco tan pesadas como los otros clústeres.

# %% [markdown]
# ### Conclusión
#
# Para concluir, es posible notar que se logró crear una clase que pudiera recibir los datos crudos de los Juegos Panamericanos 2023, y que además lograra caracterizar los mismos de forma automática y eficiente. En este sentido, de todas maneras es necesario correr y probar los distintos métodos de la clase con sus distintas configuraciones para así poder conocer de buena forma los datos, y finalmente obtener aquello que se quiere.
#
# La clase Profiler, logra realizar un resumen de los datos entregados, limpiar los datos para distintas configuraciones, realizar gráficos simples de todas las variables, permite escalar los datos, crear clusters dentro de los datos, encontrar anomalías en los datos, también permite correr todos estos métodos de una forma predeterminada si es que no se quiere ahondar en el funcionamiento de los mismos y finalmente, una vez analizados todos los datos creados por la clase, también permite eliminar la carpeta contenedora de todos los archivos creados por la misma.
#
# La investigación realizada sobre el conjunto de datos, aplicando técnicas de clustering y detección de anomalías, revela conclusiones importantes sobre la naturaleza y estructura de los datos. Se adoptó una estrategia de sampleo de 1/16 del conjunto total, utilizando OneHotEncoder para los datos categóricos. Este enfoque permitió un equilibrio entre la precisión y eficiencia computacional, esencial en el manejo de grandes volúmenes de datos.
#
# En el proceso de clusterización se utilizó el algoritmo Kmeans, enfocado en las variables numéricas. El método del codo ayudó a identificar cinco clusters óptimos, cada uno con características distintivas, como se evidenció en las gráficas de PCA y en el análisis de distribución de variables como la edad, el peso, la altura y el año. Esta segmentación refleja patrones subyacentes en los datos, donde cada cluster representa un subgrupo con atributos físicos y temporales diferenciados, brindando una comprensión más profunda de las tendencias y características del conjunto de datos.
#
# Por otro lado, la detección de anomalías se llevó a cabo mediante el algoritmo IsolationForest. Este enfoque, combinado con técnicas de preprocesamiento como OneHotEncoder y escalado logarítmico, fue efectivo para manejar tanto las variables numéricas como categóricas. La visualización de anomalías a través de PCA reveló instancias atípicas dispersas en el conjunto de datos, diferenciándose claramente de los patrones normales. Estas anomalías, que no presentaban una agrupación específica ni características comunes, sugieren comportamientos atípicos y particulares y no como agrupación de datos atípicos.
#
# Los hallazgos de este estudio, centrados en la segmentación y detección de anomalías, tienen aplicaciones específicas y valiosas.
#
# Primero, la segmentación efectiva de los datos históricos de los deportistas proporciona insights valiosos para la preparación y planificación de futuras ediciones de los juegos. Al entender las tendencias y características de los participantes pasados, los organizadores pueden optimizar aspectos como la logística, la asignación de recursos, y la promoción de eventos, asegurando que Santiago 2023 sea un éxito resonante y un símbolo de resiliencia nacional.
#
# Además, la detección de anomalías en los datos históricos no solo ayuda a identificar patrones atípicos o posibles errores en la recopilación de datos, sino que también puede ser crucial para descubrir tendencias emergentes o talentos excepcionales. Esto podría guiar a los entrenadores y equipos nacionales en la identificación de futuros atletas con alto potencial o en la adaptación de sus estrategias de entrenamiento y desarrollo deportivo.
#
# En resumen, este análisis no solo enriquece la organización y realización de los Juegos de Santiago 2023, sino que también actúa como una herramienta estratégica para fortalecer el deporte y el espíritu olímpico y deportivo en Chile. En un momento donde el país busca símbolos de unidad y progreso, este estudio de datos históricos de los deportistas se convierte en un pilar para fomentar la excelencia deportiva y la cohesión social.
