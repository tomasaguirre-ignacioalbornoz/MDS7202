# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Primavera 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Ignacio Meza, Gabriel Iturra
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Arturo Lazcano, Angelo Muñoz

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Tomás Aguirre
# - Nombre de alumno 2: Ignacio Albornoz

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/tomasaguirre-ignacioalbornoz/MDS7202

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**
# - Asistencia **obligatoria** a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.
# - **Ausentes tienen nota máxima 6.0**.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es un sistema de control de versiones que permite a desarrolladores, o personas que estén trabajando colaborativamente en ciertos proyectos, a tener un control sobre los archivos generados a lo largo del tiempo. En este sentido, es mayoritariamente utilizado por desarrolladores para tener un seguimiento de los cambios realizados en el código fuente de un proyecto. De esta manera resulta más fácil el trabajar colaborativamente, permitiendo que se trabaje en ramas paralelas, ver los cambios de los demás miembros, eliminar cambios que convergieron a un error, etc.
#
# 2.
#
# 3. En Git, un hash es una suma de comprobación que le da un identificador único a los archivos en función de su contenido, de manera que no se pueda cambiar los contenidos del mismo, o su directorio, sin que Git pueda identificarlo. Este identificador es una cadena de cuarenta caracteres hexadecimales que es generado por un algoritmo matemático llamado SHA-1.
# En un commit, el hash se utiliza para la identificación única de ese commit y rastrear su historia. Por ejemplo, si se quiere buscar un commit en específico donde se hizo X cambio, entonces se puede utilizar el hash de ese commit para encontrarlo.
#
# 4.
#
# 5. Crear un repositorio:
# - git init: Este comando crea un nuevo repositorio en el directorio actual.
# - git clone: Este comando a grnades rasgos es una combinación de distintos comandos que, una vez ejecutados, crea una copia de un repositorio Git que ya existía previamente en un nuevo directorio.
# Seguimiento a cambios:
# - git status: Este comando muestra el estado del repositorio. Este incluye archivos que fueron agregados al índice, archivos que han sido modificados pero no agregados al índice, y archivos que han sido eliminados.
# - git diff: Este comando muestra las diferencias en líneas agregadas, modificadas y eliminadas entre dos commits.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. dkfhdkf
#
# 7. Falso, git clone copia y descarga un repositorio remoto a local, mientras que git pull descarga los cambios efectuados en el repositorio remoto desde la última vez que se actualizó.
#
# 8. dlfvnd
#
# 9. Verdadero, hay distintos comandos que permiten hacer esto, como por ejemplo, git checkout -nombre-archivo-, que restaura el archivo al estado en el que estaba en el commit anterior. Por otro lado, está el comando git reset, que permite volver a diferentes versiones del código.
#
# 10. dfbdkjhfv

# %% [markdown]
# Por último, investigue y comente para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos)
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 11. Este comando sirve para hacer un guardado temporal de los cambios realizados dentro del mismo directorio de trabajo. Esto se hace generalmente para cambiar de branch o de proyecto sin perder el progreso realizado, y sin necesidad de hacer un commit. Una vez se quiera volver a trabajar con los archivos guardados, se puede ejecutar el comando 'git stash list' para acceder a los archivos almacenados en stash. Por otro lado, también se puede utilizar para deshacer cambios almacenados en stash sin eliminar el commit original, o simplemente aplicar esos cambios en caso contrario.
#
# 12. skcvbskdn

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1 (Tomás):</code> https://github.com/TomasAAM/TomasAAM
#
# <code>Link Presentacion 2 (Ignacio):</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> En primer lugar, se tienen las branch new_features y fix_ifs. Cronológicamente, se crea primero la branch new_features, donde se se hace un commit llamado "primer commit" en el cual se crea un archive readme.md en el cual se menciona el obejtivo del proyecto y se le incluye una imagen decorativa. Además se crea un archivo main.py que no está terminado. Posteriormente hay un nuevo commit llamado "se agrega funcion" en el cual al mismo archivo main.py se le agrega la función animales. Finalmente, se hace un último commit llamado "Se separa el proyecto en modulos", donde la funcion animales se pasa a un archivo .py aparte, y este se importa en el archivo main.py. Ahora, antes de hacer el último commit de la branch new_features, se creó la branch fix_ifs, donde se arregló un problema que existía con los ifs. Sin embargo, este arreglo no está presente en la versión "final" presente en la rama main por lo que se mantiene el error de los ifs en el programa final.
# Ahora, viendo los commits realizados, se podría decir que conociendo el contexto de trabajo en el que se está, son lo suficientemente informativos. Sin embargo es necesario ver el código para poder entender de buena forma qué es a lo que se refieren.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> Los commits mencionados están en orden cronológico de arriba hacia abajo. La diferencia entre el primero y el segundo es que en el primero la funcion animales se encuentra en el archivo main.py. Sin embargo, en el segundo commit esta función es llevada al archivo animales.py. de esta manera, se deja disponible la función animales en main.py, pero a través de un import.
# Luego, la diferencia entre el segundo commit y el tercero es que en el segundo existía un error en el archivo main.py, donde para ciertos animales el programa arrojaba un error debido a los ifs. Este error es arreglado en este último commit cambiando el segundo y tercer if de la función por elifs.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code> Se crea una nueva rama a partir de la rama main. Aquí se realiza un merge con la rama que arregla el problema de los ifs, quedándose con el archivo main.py de esta última rama. Ahora, se cortaría la función animales del archivo main.py, que tiene los ifs arreglados, y se pegaría en el archivo animales.py. Además se agrega el import correspondiente de la función animales en el archivo main.py.
# Finalmente, el archivo animales.py quedaría así:
# ```python
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
# ```
#
# Y el archivo main.py:
#
# ```python
# from animales import animales
#
# if __name__ == '__main__':
#     print("Ingrese el animalito para saber que dice:")
#     animal = input()
#     animales(animal)
# ```

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=87110296-876e-426f-b91d-aaf681223468' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
